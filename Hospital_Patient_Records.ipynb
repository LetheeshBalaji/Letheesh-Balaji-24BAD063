# %% [markdown]
# <a href="https://colab.research.google.com/github/LetheeshBalaji/Letheesh-Balaji-24BAD063/blob/main/Hospital_Patient_Records.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#Letheesh Balaji-24BAD063

# %%
df=pd.read_csv(r'/content/diabetes.csv')
#Letheesh Balaji-24BAD063

# %%
# Glucose Histogram
plt.hist(df["Glucose"], bins=20)
plt.title("Glucose Level Distribution")
plt.xlabel("Glucose")
plt.ylabel("Frequency")
plt.show()
#Letheesh Balaji-24BAD063

# %%
# Age Boxplot
plt.boxplot(df["Age"])
plt.title("Age Distribution")
plt.show()
#Letheesh Balaji-24BAD063
