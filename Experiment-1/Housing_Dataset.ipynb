# %% [markdown]
# <a href="https://colab.research.google.com/github/LetheeshBalaji/Letheesh-Balaji-24BAD063/blob/main/Housing_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#Letheesh Balaji-24BAD063

# %%
df=pd.read_csv(r"/content/Housing.csv")

# %%
plt.scatter(df["area"], df["price"])
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show()
#Letheesh Balaji-24BAD063

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()
#Letheesh Balaji-24BAD063
