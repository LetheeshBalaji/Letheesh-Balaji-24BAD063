# %% [markdown]
# <a href="https://colab.research.google.com/github/LetheeshBalaji/Letheesh-Balaji-24BAD063/blob/main/Banking_Customer_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#Letheesh Balaji-24BAD063

# %%
df = pd.read_csv("/content/marketing_campaign.csv", sep="\t")
#Letheesh Balaji-24BAD063

# %%
df.head()
#Letheesh Balaji-24BAD063
# Out:
#   ID,Year_Birth,Education,Marital_Status,Income,Kidhome,Teenhome,Dt_Customer,Recency,MntWines,MntFruits,MntMeatProducts,MntFishProducts,MntSweetProducts,MntGoldProds,NumDealsPurchases,NumWebPurchases,NumCatalogPurchases,NumStorePurchases,NumWebVisitsMonth,AcceptedCmp3,AcceptedCmp4,AcceptedCmp5,AcceptedCmp1,AcceptedCmp2,Complain,Z_CostContact,Z_Revenue,Response
# 0  5524,1957,Graduation,Single,58138,0,0,04-09-20...
# 1  2174,1954,Graduation,Single,46344,1,1,08-03-20...
# 2  4141,1965,Graduation,Together,71613,0,0,21-08-...
# 3  6182,1984,Graduation,Together,26646,1,0,10-02-...
# 4  5324,1981,PhD,Married,58293,1,0,19-01-2014,94,...

# %%
df.tail()
#Letheesh Balaji-24BAD063
# Out:
#      ID,Year_Birth,Education,Marital_Status,Income,Kidhome,Teenhome,Dt_Customer,Recency,MntWines,MntFruits,MntMeatProducts,MntFishProducts,MntSweetProducts,MntGoldProds,NumDealsPurchases,NumWebPurchases,NumCatalogPurchases,NumStorePurchases,NumWebVisitsMonth,AcceptedCmp3,AcceptedCmp4,AcceptedCmp5,AcceptedCmp1,AcceptedCmp2,Complain,Z_CostContact,Z_Revenue,Response
# 2235  10870,1967,Graduation,Married,61223,0,1,13-06-...
# 2236  4001,1946,PhD,Together,64014,2,1,10-06-2014,56...
# 2237  7270,1981,Graduation,Divorced,56981,0,0,25-01-...
# 2238  8235,1956,Master,Together,69245,0,1,24-01-2014...
# 2239  9405,1954,PhD,Married,52869,1,1,15-10-2012,40,...

# %%
df.shape
#Letheesh Balaji-24BAD063
# Out:
# (2240, 1)

# %%
df.info()
#Letheesh Balaji-24BAD063
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                    --------------  -----
# ...

# %%
df.describe()
#Letheesh Balaji-24BAD063
# Out:
#        ID,Year_Birth,Education,Marital_Status,Income,Kidhome,Teenhome,Dt_Customer,Recency,MntWines,MntFruits,MntMeatProducts,MntFishProducts,MntSweetProducts,MntGoldProds,NumDealsPurchases,NumWebPurchases,NumCatalogPurchases,NumStorePurchases,NumWebVisitsMonth,AcceptedCmp3,AcceptedCmp4,AcceptedCmp5,AcceptedCmp1,AcceptedCmp2,Complain,Z_CostContact,Z_Revenue,Response
# count                                                2240
# unique                                               2240
# top     1448,1963,Master,Married,33562,1,2,25-06-2014,...
# freq                                                    1

# %%
df.isnull().sum()
#Letheesh Balaji-24BAD063
# Out:
# ID,Year_Birth,Education,Marital_Status,Income,Kidhome,Teenhome,Dt_Customer,Recency,MntWines,MntFruits,MntMeatProducts,MntFishProducts,MntSweetProducts,MntGoldProds,NumDealsPurchases,NumWebPurchases,NumCatalogPurchases,NumStorePurchases,NumWebVisitsMonth,AcceptedCmp3,AcceptedCmp4,AcceptedCmp5,AcceptedCmp1,AcceptedCmp2,Complain,Z_CostContact,Z_Revenue,Response    0
# dtype: int64

# %%
df = pd.read_csv("/content/marketing_campaign.csv", sep=",")
df['Age'] = 2026 - df['Year_Birth']
#Letheesh Balaji-24BAD063

# %%
plt.figure()
df['Age'].value_counts().sort_index().plot(kind='bar')
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.title("Age Distribution")
plt.show()
#Letheesh Balaji-24BAD063

# %%
plt.figure()
sns.boxplot(x=df['Age'])
plt.title("Age Boxplot")
plt.show()
#Letheesh Balaji-24BAD063

# %%
plt.figure()
sns.boxplot(x=df['Income'])
plt.title("Income Distribution")
plt.show()
#Letheesh Balaji-24BAD063

# %%
df['Income'].dropna().plot(kind='hist', bins=20)
plt.xlabel("Income")
plt.ylabel("Customers")
plt.title("Income Distribution")
plt.show()
#Letheesh Balaji-24BAD063

# %%
df['Total_Spending'] = (
    df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] +
    df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']
)
#Letheesh Balaji-24BAD063

# %%
plt.figure()
sns.boxplot(x=df['Total_Spending'])
plt.title("Total Spending Distribution")
plt.show()
#Letheesh Balaji-24BAD063
